# %%
# !pip install -U wapi-python
# Out:
# ...
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    -------------------- ------------------- 245.8/491.3 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  481.3/491.3 kB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 4.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\cleme\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import wapi
import pandas as pd

# %%
session = wapi.Session(client_id='jUn5G3FbX9oZDehE9NV650pkq2yvpIIJ', client_secret='pSn12RSA7wJCqC8sxo.KtgemOCSZGfZ2RctKnJU0EM4BL.VdBwbdNH.vQExN1m2I54_75mWtIWus_PokuV2s8a9b56RhzxG27_pb')

# %%
curve = session.get_curve(name='pri ch spot €/mwh cet h a')
ts = curve.get_data(data_from="2003-06-01", data_to="2022-06-08")

# %%
pd_ts = ts.to_pandas()
pd_ts.plot()
# Out:
# <Axes: >
